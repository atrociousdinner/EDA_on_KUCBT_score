# %%
import pandas as pd
import tabula as tb

# %%
# path_2022 = '/home/atrocity101/Desktop/repos/pandas/kucbt_eda/pdf/KUCBT_Final_Score_20221669868171.pdf'
# path_2023 = '/home/atrocity101/Desktop/repos/pandas/kucbt_eda/pdf/CBT_Score_with_Prog_2023_09_15_Print1694768486.pdf'
# path_2024 = '/home/atrocity101/Desktop/repos/pandas/kucbt_eda/pdf/CBT_Pass_List_2024_1_sept1725180337.pdf'
# path_2025 = '/home/atrocity101/Desktop/repos/pandas/kucbt_eda/pdf/KUCAT_CBT_2025_Rank_List.pdf'
ce_path_2025 = '/home/atrocity101/Desktop/repos/pandas/kucbt_eda/pdf/KUCAT-CBT-2025-CE.pdf'

# %%
# dfs_2022 = tb.read_pdf(path_2022, pages = 'all', stream=True, pandas_options = {'header':None})
# dfs_2023 = tb.read_pdf(path_2023, pages = 'all', lattice = True)
# dfs_2024 = tb.read_pdf(path_2024, pages = 'all', lattice = True)
# dfs_2025 = tb.read_pdf(path_2025, pages = 'all', lattice = True)
dfs_2025_ce = tb.read_pdf(ce_path_2025, pages = 'all', lattice = True)

# %%
dfs_2025_ce[0].head()
# Out:
#    S. No.        KUCBT No.                    Name  CBT Score
# 0       1  KUCBT_2025_2650            Sumyak Limbu       1543
# 1       2  KUCBT_2025_1451           Prabin Dhakal       1522
# 2       3  KUCBT_2025_1750             Sudivya Sah       1515
# 3       4   KUCBT_2025_849           Aavash Uprety       1500
# 4       5   KUCBT_2025_450  Chandan Kumar Panjiyar       1493

# %%
#Discarding 2025 as it doesn't have score

# %%
for i,d in enumerate(dfs_2025_ce):
    print(f"Page{i+1}: ${d.shape} and columns -> {list(d.columns)}")
# Out:
# Page1: $(41, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page2: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page3: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page4: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page5: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page6: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page7: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page8: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page9: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page10: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page11: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page12: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page13: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page14: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page15: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page16: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page17: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page18: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page19: $(40, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page20: $(41, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page21: $(40, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page22: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page23: $(42, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']
# Page24: $(6, 4) and columns -> ['S. No.', 'KUCBT No.', 'Name', 'CBT Score']

# %%
full_df = pd.concat(dfs_2025_ce, ignore_index = True)

# %%
full_df.columns
# Out:
# Index(['S. No.', 'KUCBT No.', 'Name', 'CBT Score'], dtype='object')

# %%
full_df.head()
# Out:
#    S. No.        KUCBT No.                    Name  CBT Score
# 0       1  KUCBT_2025_2650            Sumyak Limbu       1543
# 1       2  KUCBT_2025_1451           Prabin Dhakal       1522
# 2       3  KUCBT_2025_1750             Sudivya Sah       1515
# 3       4   KUCBT_2025_849           Aavash Uprety       1500
# 4       5   KUCBT_2025_450  Chandan Kumar Panjiyar       1493

# %%
full_df['Program'] = 'BE in Computer Engineering'
full_df
# Out:
#            KUCBT No.                    Name  CBT Score  \
# 0    KUCBT_2025_2650            Sumyak Limbu       1543
# 1    KUCBT_2025_1451           Prabin Dhakal       1522
# 2    KUCBT_2025_1750             Sudivya Sah       1515
# 3     KUCBT_2025_849           Aavash Uprety       1500
# 4     KUCBT_2025_450  Chandan Kumar Panjiyar       1493
# ..               ...                     ...        ...
# 961  KUCBT_2025_1407        Mahim Lamichhane        296
# 962  KUCBT_2025_2795          Manisha Bhatta        293
# 963  KUCBT_2025_3187            Nitya Mishra        281
# 964  KUCBT_2025_1264            Ganapati Ray        261
# 965  KUCBT_2025_3196          Smarika Nepali        254
#
#                         Program
# 0    BE in Computer Engineering
# 1    BE in Computer Engineering
# 2    BE in Computer Engineering
# 3    BE in Computer Engineering
# 4    BE in Computer Engineering
# ..                          ...
# 961  BE in Computer Engineering
# 962  BE in Computer Engineering
# 963  BE in Computer Engineering
# 964  BE in Computer Engineering
# 965  BE in Computer Engineering
#
# [966 rows x 4 columns]

# %%
full_df.columns = ['id', 'Name', 'KUCBT Score', 'Program']

# %%
full_df.head()
# Out:
#                 id                    Name  KUCBT Score  \
# 0  KUCBT_2025_2650            Sumyak Limbu         1543
# 1  KUCBT_2025_1451           Prabin Dhakal         1522
# 2  KUCBT_2025_1750             Sudivya Sah         1515
# 3   KUCBT_2025_849           Aavash Uprety         1500
# 4   KUCBT_2025_450  Chandan Kumar Panjiyar         1493
#
#                       Program
# 0  BE in Computer Engineering
# 1  BE in Computer Engineering
# 2  BE in Computer Engineering
# 3  BE in Computer Engineering
# 4  BE in Computer Engineering

# %%
full_df.isna().sum()
# Out:
# id             0
# Name           0
# KUCBT Score    0
# Program        0
# dtype: int64

# %%
#Do not touch within this boundary

# %%
full_df[full_df['Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [id, Name, KUCBT Score, Program]
# Index: []

# %%
full_df = full_df.drop(index = 1784).copy()

# %%
#Do not touch within this boundary

# %%
full_df.isna().sum()
# Out:
# id             0
# Name           0
# KUCBT Score    0
# Program        0
# dtype: int64

# %%
full_df.columns
# Out:
# Index(['id', 'Name', 'KUCBT Score', 'Program'], dtype='object')

# %%
full_df.dtypes
# Out:
# id             object
# Name           object
# KUCBT Score     int64
# Program        object
# dtype: object

# %%
full_df['KUCBT Score'].dtype
# Out:
# dtype('int64')

# %%
mask = full_df['KUCBT Score'].astype(str).str.contains('*', regex = False)
full_df[mask]
# Out:
# Empty DataFrame
# Columns: [id, Name, KUCBT Score, Program]
# Index: []

# %%
full_df['KUCBT Score'] = full_df['KUCBT Score'].astype(str).str.replace('*', '', regex=False).str.strip()

# %%
full_df['KUCBT Score'] = pd.to_numeric(full_df['KUCBT Score'], errors = 'coerce').astype('Int64')

# %%
full_df.dtypes
# Out:
# id             object
# Name           object
# KUCBT Score     Int64
# Program        object
# dtype: object

# %%
full_df.to_csv("./csv/version3/2025_final_ce.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 full_df.to_csv("./csv/version3/2025_final_ce.csv", index = False)
#
# File ~/myenv/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/myenv/lib/python3.12/site-packages/pandas/core/generic.py:3989, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3978 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3980 formatter = DataFrameFormatter(
#    3981     frame=df,
#    3982     header=header,
#    (...)   3986     decimal=decimal,
#    3987 )
# -> 3989 return DataFrameRenderer(formatter).to_csv(
#    3990     path_or_buf,
#    3991     lineterminator=lineterminator,
#    3992     sep=sep,
#    3993     encoding=encoding,
#    3994     errors=errors,
#    3995     compression=compression,
#    3996     quoting=quoting,
#    3997     columns=columns,
#    3998     index_label=index_label,
#    3999     mode=mode,
#    4000     chunksize=chunksize,
#    4001     quotechar=quotechar,
#    4002     date_format=date_format,
#    4003     doublequote=doublequote,
#    4004     escapechar=escapechar,
#    4005     storage_options=storage_options,
#    4006 )
#
# File ~/myenv/lib/python3.12/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)   1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/myenv/lib/python3.12/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)    267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~/myenv/lib/python3.12/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/myenv/lib/python3.12/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'csv/version3'

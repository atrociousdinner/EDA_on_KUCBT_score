# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_2022 = pd.read_csv('./csv/version3/2022_final.csv')
df_2023 = pd.read_csv('./csv/version3/2023_final.csv')
df_2024 = pd.read_csv('./csv/version3/2024_final.csv')

# %%
df_2023
# Out:
#                    id               name  kucbt_score  \
# 0        KUCAT_2023_1     Shreeyut Thapa         1224
# 1        KUCAT_2023_2     Kiyoshi Pandey          672
# 2        KUCAT_2023_3  Anmol Kumar Yadav          622
# 3        KUCAT_2023_4    Shailesh Paudel          578
# 4        KUCAT_2023_5      Yubraj Panthi          674
# ...               ...                ...          ...
# 2258  KUCAT_2023_3208       Sabin Shrees          578
# 2259  KUCAT_2023_3210       Lajjita Bhaa          587
# 2260  KUCAT_2023_3211        Anup Khanal          731
# 2261  KUCAT_2023_3212      Prasoon Dahal          821
# 2262  KUCAT_2023_3214   Kelvin Sangroula          755
#
#                                                 program first_name gender
# 0                            BE in Computer Engineering   shreeyut      m
# 1                            BE in Computer Engineering    kiyoshi      f
# 2                             BE in Geomacs Engineering      anmol      m
# 3                            BE in Computer Engineering   shailesh      m
# 4     BE in Civil Engineering (Specializaon in Hydro...     yubraj      m
# ...                                                 ...        ...    ...
# 2258  BE in Civil Engineering (Specializaon in Hydro...      sabin      m
# 2259                              BArch in Architecture    lajjita      f
# 2260                         BE in Computer Engineering       anup      m
# 2261                         BE in Computer Engineering    prasoon      m
# 2262  BE in Mechanical Engineering(Design and Manufa...     kelvin      m
#
# [2263 rows x 6 columns]

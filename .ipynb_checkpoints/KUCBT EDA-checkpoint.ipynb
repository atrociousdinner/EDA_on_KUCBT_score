# %%
import pandas as pd
import tabula as tb

# %%
# path_2022 = '/home/atrocity101/Desktop/repos/pandas/kucbt_eda/pdf/KUCBT_Final_Score_20221669868171.pdf'
# path_2023 = '/home/atrocity101/Desktop/repos/pandas/kucbt_eda/pdf/CBT_Score_with_Prog_2023_09_15_Print1694768486.pdf'
# path_2024 = '/home/atrocity101/Desktop/repos/pandas/kucbt_eda/pdf/CBT_Pass_List_2024_1_sept1725180337.pdf'
# path_2025 = '/home/atrocity101/Desktop/repos/pandas/kucbt_eda/pdf/KUCAT_CBT_2025_Rank_List.pdf'

# %%
# dfs_2022 = tb.read_pdf(path_2022, pages = 'all', stream=True, pandas_options = {'header':None})
# dfs_2023 = tb.read_pdf(path_2023, pages = 'all', lattice = True)
# dfs_2024 = tb.read_pdf(path_2024, pages = 'all', lattice = True)
# dfs_2025 = tb.read_pdf(path_2025, pages = 'all', lattice = True)

# %%
dfs_2025[0].head()
# Out:
#       KUCBT No.              Name  \
# 0  KUCBT_2025_1      Nabin Khadka
# 1  KUCBT_2025_2  Sudishna Paudyal
# 2  KUCBT_2025_3       Sakar Dahal
# 3  KUCBT_2025_4       Roshni Shah
# 4  KUCBT_2025_5     Asmita Basnet
#
#                                      Applied Program  Rank
# 0                              BSc in Bioinformatics  1952
# 1                           Bachelor in Data Science  2298
# 2  BE in Civil Engineering (Specialization in Hyd...  3080
# 3                         BE in Computer Engineering   664
# 4                              BArch in Architecture  1276

# %%
#Discarding 2025 as it doesn't have score

# %%
for i,d in enumerate(dfs_2024):
    print(f"Page{i+1}: ${d.shape} and columns -> {list(d.columns)}")
# Out:
# Page1: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page2: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page3: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page4: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page5: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page6: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page7: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page8: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page9: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page10: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page11: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page12: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page13: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page14: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page15: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page16: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page17: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page18: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page19: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page20: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page21: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page22: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page23: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page24: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page25: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page26: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page27: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page28: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page29: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page30: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page31: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page32: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page33: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page34: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page35: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page36: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page37: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page38: $(46, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']
# Page39: $(37, 4) and columns -> ['KUCBT No.', 'Name', 'CBT Score', 'Apply Program']

# %%
full_df = pd.concat(dfs_2024, ignore_index = True)

# %%
full_df.columns
# Out:
# Index(['KUCBT No.', 'Name', 'CBT Score', 'Apply Program'], dtype='object')

# %%
full_df.head()
# Out:
#       KUCBT No.             Name  CBT Score  \
# 0  KUSoE_2024_1  Aashutosh Singh      721.0
# 1  KUSoE_2024_2    PRANAY MALLIK      641.0
# 2  KUSoE_2024_3     SARJU SAHANI      709.0
# 3  KUSoE_2024_6      Ashmit Shah      721.0
# 4  KUSoE_2024_7  Surasa Silpakar      873.0
#
#                                        Apply Program
# 0                         BE in Computer Engineering
# 1                         BE in Computer Engineering
# 2                              BArch in Architecture
# 3  BE in Electrical & Electronic Engineering (Com...
# 4                         BE in Computer Engineering

# %%
full_df.columns = ['id', 'Name', 'KUCBT Score', 'Program']

# %%
full_df.head()
# Out:
#              id             Name  KUCBT Score  \
# 0  KUSoE_2024_1  Aashutosh Singh        721.0
# 1  KUSoE_2024_2    PRANAY MALLIK        641.0
# 2  KUSoE_2024_3     SARJU SAHANI        709.0
# 3  KUSoE_2024_6      Ashmit Shah        721.0
# 4  KUSoE_2024_7  Surasa Silpakar        873.0
#
#                                              Program
# 0                         BE in Computer Engineering
# 1                         BE in Computer Engineering
# 2                              BArch in Architecture
# 3  BE in Electrical & Electronic Engineering (Com...
# 4                         BE in Computer Engineering

# %%
full_df.isna().sum()
# Out:
# id             0
# Name           1
# KUCBT Score    1
# Program        1
# dtype: int64

# %%
full_df[full_df['Name'].isna()]
# Out:
#                                                      id Name  KUCBT Score  \
# 1784  *Withheld candidates should contact with origi...  NaN          NaN
#
#      Program
# 1784     NaN

# %%
full_df = full_df.drop(index = 1784).copy()

# %%
full_df.isna().sum()
# Out:
# id             0
# Name           0
# KUCBT Score    0
# Program        0
# dtype: int64

# %%
full_df.columns
# Out:
# Index(['id', 'Name', 'KUCBT Score', 'Program'], dtype='object')

# %%
full_df.dtypes
# Out:
# id              object
# Name            object
# KUCBT Score    float64
# Program         object
# dtype: object

# %%
full_df['KUCBT Score'].dtype
# Out:
# dtype('float64')

# %%
mask = full_df['KUCBT Score'].astype(str).str.contains('*', regex = False)
full_df[mask]
# Out:
# Empty DataFrame
# Columns: [id, Name, KUCBT Score, Program]
# Index: []

# %%
full_df['KUCBT Score'] = full_df['KUCBT Score'].astype(str).str.replace('*', '', regex=False).str.strip()

# %%
full_df['KUCBT Score'] = pd.to_numeric(full_df['KUCBT Score'], errors = 'coerce').astype('Int64')

# %%
full_df.dtypes
# Out:
# id             object
# Name           object
# KUCBT Score     Int64
# Program        object
# dtype: object

# %%
full_df.to_csv("./csv/2024_final.csv", index = False)
